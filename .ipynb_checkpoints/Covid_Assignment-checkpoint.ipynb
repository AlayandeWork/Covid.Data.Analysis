# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
covid = pd.read_csv("Covid_Data.csv")

# %%
covid.head(2)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
#
# [2 rows x 21 columns]

# %%
covid.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
covid.rename(columns={'CLASIFFICATION_FINAL': 'CLASSIFICATION_FINAL'}, inplace=True)
covid.rename(columns={'HIPERTENSION': 'HYPERTENSION'}, inplace=True)

# %%
sex_class = {
    "1": "Female",
    "2": "Male"
}
covid["SEX"] = covid["SEX"].astype(str).replace(sex_class)

# %%
class_final = {
    "1": "Critical",
    "2": "Medium",
    "3": "Mild"
}
covid["CLASSIFICATION_FINAL"] = covid["CLASSIFICATION_FINAL"].astype(str).map(class_final)
covid["CLASSIFICATION_FINAL"].replace(to_replace={pd.NA: "Negative or Inconclusive"}, inplace=True)

# %%
care_type = {
    "1": "Returned Home",
    "2": "Hospitalization",
    "97": "Missing Data",
    "98": "Missing Data",
    "99": "Missing Data"
}
covid["PATIENT_TYPE"] = covid["PATIENT_TYPE"].astype(str).replace(care_type)

# %%
monia = {
    "1": "Yes",
    "2": "No",
    "97": "Missing Data",
    "98": "Missing Data",
    "99": "Missing Data"
}
covid["PNEUMONIA"] = covid["PNEUMONIA"].astype(str).replace(monia)
covid["PREGNANT"] = covid["PREGNANT"].astype(str).replace(monia)
covid["DIABETES"] = covid["DIABETES"].astype(str).replace(monia)
covid["COPD"] = covid["COPD"].astype(str).replace(monia)
covid["ASTHMA"] = covid["ASTHMA"].astype(str).replace(monia)
covid["INMSUPR"] = covid["INMSUPR"].astype(str).replace(monia)
covid["HYPERTENSION"] = covid["HYPERTENSION"].astype(str).replace(monia)
covid["CARDIOVASCULAR"] = covid["CARDIOVASCULAR"].astype(str).replace(monia)
covid["RENAL_CHRONIC"] = covid["RENAL_CHRONIC"].astype(str).replace(monia)
covid["OTHER_DISEASE"] = covid["OTHER_DISEASE"].astype(str).replace(monia)
covid["OBESITY"] = covid["OBESITY"].astype(str).replace(monia)
covid["TOBACCO"] = covid["TOBACCO"].astype(str).replace(monia)
covid["USMER"] = covid["USMER"].astype(str).replace(monia)
covid["INTUBED"] = covid["INTUBED"].astype(str).replace(monia)
covid["ICU"] = covid["ICU"].astype(str).replace(monia)

# %%
covid["DATE_DIED"] = covid["DATE_DIED"].astype(str).replace("9999-99-99","9999-01-02")

# %%
covid["SEX"].value_counts().plot.bar(title = 'Number of Males and Females')
plt.xlabel("Gender")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
covid["SEX"].value_counts()
# Out:
# SEX
# Female    525064
# Male      523511
# Name: count, dtype: int64

# %%
sns.kdeplot(x = "AGE", data = covid )
# Out:
# <Axes: xlabel='AGE', ylabel='Density'>

# %%
covid["PATIENT_TYPE"].value_counts().plot.bar(title = 'Patients That Returned Home or Hosptalized')
plt.xlabel("Patient Type")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
def dod_count():
    Alive = 0
    Dead = 0

    for i in covid["DATE_DIED"]:
        if i == "9999-01-02":
            Alive += 1
        else:
            Dead += 1

    return Alive,Dead

# %%
Alive, Dead = dod_count()

labels = ['Alive', 'Dead']
counts = [Alive, Dead]

plt.bar(labels, counts)
plt.xlabel('Patient Status')
plt.ylabel('Count')
plt.title('Number of Dead or Alive Patients')
# Out:
# Text(0.5, 1.0, 'Number of Dead or Alive Patients')

# %%
covid.head(3)
# Out:
#   USMER  MEDICAL_UNIT     SEX     PATIENT_TYPE   DATE_DIED       INTUBED  \
# 0    No             1  Female    Returned Home  03/05/2020  Missing Data
# 1    No             1    Male    Returned Home  03/06/2020  Missing Data
# 2    No             1    Male  Hospitalization  09/06/2020           Yes
#
#   PNEUMONIA  AGE      PREGNANT DIABETES  ... ASTHMA INMSUPR HYPERTENSION  \
# 0       Yes   65            No       No  ...     No      No          Yes
# 1       Yes   72  Missing Data       No  ...     No      No          Yes
# 2        No   55  Missing Data      Yes  ...     No      No           No
#
#   OTHER_DISEASE CARDIOVASCULAR OBESITY RENAL_CHRONIC TOBACCO  \
# 0            No             No      No            No      No
# 1            No             No     Yes           Yes      No
# 2            No             No      No            No      No
#
#        CLASSIFICATION_FINAL           ICU
# 0                      Mild  Missing Data
# 1  Negative or Inconclusive  Missing Data
# 2                      Mild            No
#
# [3 rows x 21 columns]

# %%
covid["DIABETES"].value_counts().plot.bar(title = 'Patients That have Diabetes or Not')
plt.xlabel("Diabetes Status")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
covid["DIABETES"].value_counts()
# Out:
# DIABETES
# No              920248
# Yes             124989
# Missing Data      3338
# Name: count, dtype: int64

# %%
covid["OBESITY"].value_counts().plot.bar(title = 'Patients That Obese or Not')
plt.xlabel("Obesity Status")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
covid["OBESITY"].value_counts()
# Out:
# OBESITY
# No              885727
# Yes             159816
# Missing Data      3032
# Name: count, dtype: int64

# %%
covid["HYPERTENSION"].value_counts().plot.bar(title = 'Patients that are Hypertensive or Not')
plt.xlabel("Hypertension Status")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
covid["INMSUPR"].value_counts().plot.bar(title = 'Patients that are Immunosupressed or Not')
plt.xlabel("Immunosupression Status")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
covid["COPD"].value_counts().plot.bar(title = 'Patients that Have Chronic Respiratory Disease or Not')
plt.xlabel("COPD Status")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
covid["CARDIOVASCULAR"].value_counts().plot.bar(title = 'Patients that have CARDIOVASCULAR disease or Not')
plt.xlabel("CARDIOVASCULAR Status")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
covid["RENAL_CHRONIC"].value_counts().plot.bar(title = 'Patients that have Kidney disease or Not')
plt.xlabel("RENAL CHRONIC Status")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
covid.to_csv("Final Covid Project.csv", index=False)

# %%
df_count = df_intro[(df_intro["Sex"] == "male") & (df_intro["Survived"] == 0)]
df_count["Sex"].count()
